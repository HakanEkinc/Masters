# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import func_notebook as nbk
from pathlib import Path
from scipy.signal import find_peaks
from scipy.ndimage import gaussian_filter1d

# %%
filepath = '/disk/gfs_atp/hekinc/Master_measurements/alpine_cold/led2.5Vamp-2+3sipm+54temp-90c/RAW/DataR_CH0@DT5730S_63863_led2.5Vamp-2+3sipm+54temp-90c.CSV'
conditions = [-90,2.5,54]
nbk.plot_sample_signals(filepath,conditions, num_samples=8)
