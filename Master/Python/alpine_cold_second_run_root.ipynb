# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import func_notebook as nbk
from pathlib import Path
from scipy.signal import find_peaks
from scipy.ndimage import gaussian_filter1d
from itertools import islice
import pyarrow as py
import uproot
import awkward_pandas

# %%
filepath = '/disk/gfs_atp/hekinc/Master_measurements/TESTRUN_ROOT.root'
data = nbk.analyse_root_data(filepath)
# Out:
# Processing ch02...
# Processing ch03...
# Processing ch04...
# Processing ch05...
# Processing ch06...
# Processing ch14...
# Processing ch15...
# Processing ch16...
# Data successfully saved to /disk/gfs_atp/hekinc/Master_measurements/test_root_to_parquet.parquet

# %%
print(data['channel'])
# Out:
# 0         ch02
# 1         ch02
# 2         ch02
# 3         ch02
# 4         ch02
#           ...
# 480011    ch16
# 480012    ch16
# 480013    ch16
# 480014    ch16
# 480015    ch16
# Name: channel, Length: 480016, dtype: str
