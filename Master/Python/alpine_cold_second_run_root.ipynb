# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import func_notebook as nbk
from pathlib import Path
from scipy.signal import find_peaks
from scipy.ndimage import gaussian_filter1d
from itertools import islice
import pyarrow as py
import uproot
import awkward_pandas
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
filepath = '/disk/gfs_atp/hekinc/Master_measurements/TESTRUN_ROOT.root'

# %%
data = nbk.analyse_root_data(filepath)
# Out:
# Processing ch02...
#   -> Negative polarity detected on ch02. Auto-inverting.
# Processing ch03...
#   -> Negative polarity detected on ch03. Auto-inverting.
# Processing ch04...
#   -> Negative polarity detected on ch04. Auto-inverting.
# Processing ch05...
# Processing ch06...
#   -> Negative polarity detected on ch06. Auto-inverting.
# Processing ch14...
#   -> Negative polarity detected on ch14. Auto-inverting.
# Processing ch15...
# Processing ch16...
#   -> Negative polarity detected on ch16. Auto-inverting.

# %%
# Assuming 'master_df' is your DataFrame containing 'channel' and 'peak_integral' columns

# Fit all channels and automatically generate the plots
results_dict = nbk.fit_all_channels_in_df(data, column_to_fit="peak_integral")

# The wrapper returns a dictionary of the key physics parameters, making it easy to check gains!
# Out:
# ...
#  STARTING ANALYSIS FOR: ch02
# ...
# Processing 60002 data points for ch02...
# Auto-detecting peaks...
# Physics Curve fitting converged successfully!
#
# --- Physical Fit Results for ch02 ---
# Pedestal (μ_0): 1.560759e+03
# Detector Gain:      2.601107e+03
# Pedestal Noise (σ_0): 3.043396e+00
# 1-Photon Noise (σ_1): 1.953373e+03
# χ² / NDF:           21201.38 / 400 = 53.003
# ----------------------------
# ...
#  STARTING ANALYSIS FOR: ch03
# ...
# Processing 60002 data points for ch03...
# Auto-detecting peaks...
# Physics Curve fitting converged successfully!
#
# --- Physical Fit Results for ch03 ---
# Pedestal (μ_0): -2.194536e+03
# Detector Gain:      2.148235e+03
# Pedestal Noise (σ_0): 2.468697e+01
# 1-Photon Noise (σ_1): 5.257760e+02
# χ² / NDF:           11181.12 / 395 = 28.307
# ----------------------------
# ...
#  STARTING ANALYSIS FOR: ch04
# ...
# Processing 60002 data points for ch04...
# Auto-detecting peaks...
# Physics Curve fitting converged successfully!
#
# ...

# %%
nbk.plot_sample_signals_from_root(filepath, [1,2,3])
# Out:
# Processing ch02...
# Processing ch03...
# Processing ch04...
# Processing ch05...
# Processing ch06...
# Processing ch14...
# Processing ch15...
# Processing ch16...
