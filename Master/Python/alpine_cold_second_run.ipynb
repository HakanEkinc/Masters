# %%
# %load_ext autoreload
# %autoreload 2

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import func_notebook as nbk
from pathlib import Path
from scipy.signal import find_peaks
from scipy.ndimage import gaussian_filter1d
from itertools import islice
import pyarrow as py
import uproot

# %%
filepath = '/disk/gfs_atp/hekinc/Master_measurements/TESTRUN.csv'
testname = 'testparquet'
nbk.process_csv_file_in_chunks_pandas(filepath,testname )
# Out:
#         channel         areas    sigmas      baseline
# 0             0  11062.785205  3.854663  13109.420677
# 1             0   9429.941176  5.314739  13108.853832
# 2             0  11120.877005  3.698295  13108.593583
# 3             0  11118.176471  3.591915  13110.802139
# 4             0  11040.773619  3.648130  13109.991087
# ...         ...           ...       ...           ...
# 119998        0  11453.558824  3.768261  13106.411765
# 119999        0  11361.323529  4.469426  13108.803922
# 120000        0  10928.647059  3.473578  13108.062389
# 120001        0  11584.647059  3.360895  13109.910873
# 120002        0  11440.558824  4.080325  13108.237077
#
# [120003 rows x 4 columns]

# %%
#read the parquet file
df = pd.read_parquet(f'/disk/gfs_atp/hekinc/Master_measurements/{testname}.parquet')
print(df[df['channel'] == 0].copy())
# Out:
#         channel         areas    sigmas      baseline
# 0             0  11062.785205  3.854663  13109.420677
# 1             0   9429.941176  5.314739  13108.853832
# 2             0  11120.877005  3.698295  13108.593583
# 3             0  11118.176471  3.591915  13110.802139
# 4             0  11040.773619  3.648130  13109.991087
# ...         ...           ...       ...           ...
# 119998        0  11453.558824  3.768261  13106.411765
# 119999        0  11361.323529  4.469426  13108.803922
# 120000        0  10928.647059  3.473578  13108.062389
# 120001        0  11584.647059  3.360895  13109.910873
# 120002        0  11440.558824  4.080325  13108.237077
#
# [120003 rows x 4 columns]
